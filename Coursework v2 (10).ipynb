# %% [markdown]
# # Coding Part of EC2B1 Project

# %% [markdown]
# Imports

# %%
# Import necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from get_regression_coefs import get_regression_coefs

# %% [markdown]
# # Part A Long Run Trends

# %% [markdown]
#  Data Logistics

# %%
# Set the style for the plot and figure size

plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (12, 10)
plt.rcParams['axes.titlesize'] = 15

# 1.Load the dataset from the Excel file
df = pd.read_excel('pwt100.xlsx', sheet_name = 'Data')

# 2.Extracting only the necessary columns from the dataset
columns_to_keep = ["countrycode", "year", "rgdpna", "pop", "emp", "rnna"]
df = df.loc[:, columns_to_keep]

# 3.Creating log(real GDP) 
df['log(rgdpna)'] = np.log(df["rgdpna"])

# 4.Creating log(real GDP per capita
df['log(rgdpna_pc)'] = np.log(df['rgdpna']/df['pop'])

# 5.Obtain the data for Argentina
arg_df = df.loc[df["countrycode"] == "ARG"].copy()
arg_df.drop('countrycode', axis=1, inplace=True)
arg_df.reset_index(drop=True, inplace=True)
y_arg = arg_df['log(rgdpna)']
ypc_arg = arg_df['log(rgdpna_pc)']

# 6.Obtain the data for France
fra_df = df.loc[df["countrycode"] == "FRA"].copy()
fra_df.drop('countrycode', axis=1, inplace=True)
fra_df.reset_index(drop=True, inplace=True)
y_fra = fra_df['log(rgdpna)']
ypc_fra = fra_df['log(rgdpna_pc)']

# %% [markdown]
# Data Manipulation - Argentina

# %%
# Using log models for Argentina
T = len(arg_df)

# Create regressors x1, x2, and x3
x1 = np.empty(T)
x2 = np.empty(T)
x3 = np.empty(T)

for t in range(T):
    x1[t] = 1.0
    x2[t] = t + 1
    x3[t] = (t + 1)**2

# Get the regression coefficients using the get_regression_coefs function
a_exp_quad, b1_exp_quad, b2_exp_quad = get_regression_coefs(y_arg, x1, x2, x3)

# Initialize the predicted values yhat
yhat_arg = np.empty(T)

# Compute the trend for all years
for t in range(T):
    yhat_arg[t] = a_exp_quad + b1_exp_quad * (t + 1) + b2_exp_quad * (t + 1)**2
    
# Plot RGDP trend line for Argentina
plt.plot(arg_df['year'], y_arg, label='Real GDP')
plt.plot(arg_df['year'], yhat_arg, linestyle='dashed', label='Trend Line')
plt.title('Trend Time Path of Real GDP of Argentina', size=25)
plt.xlabel('Year')
plt.ylabel('log(Real GDP)')
plt.legend()

# %%
T = len(arg_df)

# Create regressors x1, x2, and x3
x1 = np.empty(T)
x2 = np.empty(T)
x3 = np.empty(T)

for t in range(T):
    x1[t] = 1.0
    x2[t] = t + 1
    x3[t] = (t + 1)**2

# Get the regression coefficients using the get_regression_coefs function
a_exp_quad, b1_exp_quad, b2_exp_quad = get_regression_coefs(ypc_arg, x1, x2, x3)

# Initialize the predicted values yhat
ypchat_arg = np.empty(T)

# Compute the trend for all years
for t in range(T):
    ypchat_arg[t] = a_exp_quad + b1_exp_quad * (t + 1) + b2_exp_quad * (t + 1)**2
    
# Plot RGDP per capita trend line for Argentina
plt.plot(arg_df['year'], ypc_arg, label='Real GDP per capita')
plt.plot(arg_df['year'], ypchat_arg, linestyle='dashed', label='Trend Line')
plt.title('Trend Time Path of Real GDP per capita of Argentina', size=25)
plt.xlabel('Year')
plt.ylabel('log(Real GDP per capita)')
plt.legend()

# %% [markdown]
# Data Manipulation - France

# %%
# Create regressors for the log model for France
T = len(fra_df)
x1, x2, x3 = np.empty(T), np.empty(T), np.empty(T)

for t in range(T):
    x1[t] = 1.
    x2[t] = t + 1
    x3[t] = (t + 1)**2

# Estimate coefficients for the log for France
a_exp_quad, b1_exp_quad, b2_exp_quad = get_regression_coefs(y_fra, x1, x2, x3)

# Initialise predicted values yhat
yhat_fra = np.empty(T)

# Create loop to compute trend for all years
for t in range(T):
    yhat_fra[t] = a_exp_quad + b1_exp_quad * (t + 1) + b2_exp_quad * (t + 1)**2
    
# Plotting the actual and predicted values for France
plt.plot(fra_df['year'], y_fra, label='Real GDP')
plt.plot(fra_df['year'], yhat_fra, linestyle='dashed', label='Trend Line')
plt.title('Trend Time Path of Real GDP of France', size=25)
plt.xlabel('Year')
plt.ylabel('log(Real GDP)')
plt.legend()

# %%
T = len(arg_df)

# Create regressors x1, x2, and x3
x1 = np.empty(T)
x2 = np.empty(T)
x3 = np.empty(T)

for t in range(T):
    x1[t] = 1.0
    x2[t] = t + 1
    x3[t] = (t + 1)**2

# Get the regression coefficients using the get_regression_coefs function
a_exp_quad, b1_exp_quad, b2_exp_quad = get_regression_coefs(ypc_fra, x1, x2, x3)

# Initialize the predicted values yhat
ypchat_fra = np.empty(T)

# Compute the trend for all years
for t in range(T):
    ypchat_fra[t] = a_exp_quad + b1_exp_quad * (t + 1) + b2_exp_quad * (t + 1)**2
    
# Plot RGDP per capita trend line for Argentina
plt.plot(fra_df['year'], ypc_fra, label='Real GDP per capita')
plt.plot(fra_df['year'], ypchat_fra, linestyle='dashed', label='Trend Line')
plt.title('Trend Time Path of Real GDP per capita of France', size=25)
plt.xlabel('Year')
plt.ylabel('log(Real GDP per capita)')
plt.legend()

# %% [markdown]
# # Part B Production Function

# %% [markdown]
# Production function: $Y=A \times L^\alpha \times K ^{1-\alpha} $
#
# TFP is the weighted average of labour and capital input divided by output, we assume a weighting of 0.7 for labour and 0.3 for capital i.e. alpha = 0.7

# %%
alpha = 0.7

# Plot TFP for Argentina
arg_df['TFP'] = arg_df['rgdpna'] / ((arg_df['emp'])**alpha * (arg_df['rnna']**(1 - alpha)))
plt.plot(arg_df['year'], arg_df['TFP'])
plt.title('Total Factor Productivity for Argentina', size = 20)
plt.xlabel('Year')
plt.ylabel('Total Factor Productivity')
# Out:
# Text(0, 0.5, 'Total Factor Productivity')

# %%
# Plot TFP for France
fra_df['TFP'] = fra_df['rgdpna'] / ((fra_df['emp'])**alpha * (fra_df['rnna']**(1 - alpha)))
plt.plot(fra_df['year'], fra_df['TFP'])
plt.title('Total Factor Productivity for France', size = 20)
plt.xlabel('Year')
plt.ylabel('Total Factor Productivity')
# Out:
# Text(0, 0.5, 'Total Factor Productivity')

# %% [markdown]
# # Part C Growth Accounting

# %% [markdown]
# Argentina

# %%
# Calculate growth contributions
T = arg_df.shape[0]
arg_dlog_y = np.empty(T-1)
arg_dlog_A = np.empty(T-1)
arg_dlog_k = np.empty(T-1)
arg_dlog_l = np.empty(T-1)
for t in range(T-1):
    arg_dlog_y[t] = np.log(arg_df['rgdpna'][t+1]) - np.log(arg_df['rgdpna'][t])
    arg_dlog_A[t] = np.log(arg_df['TFP'][t+1]) - np.log(arg_df['TFP'][t])
    arg_dlog_k[t] = np.log(arg_df['rnna'][t+1]) - np.log(arg_df['rnna'][t])
    arg_dlog_l[t] = np.log(arg_df['emp'][t+1]) - np.log(arg_df['emp'][t])

#TFP contribution
arg_contr_TFP = arg_dlog_A / arg_dlog_y
#Capital contribution
arg_contr_k = ((1 - alpha) * arg_dlog_k) / arg_dlog_y
#Labout contribution
arg_contr_l = (alpha * arg_dlog_l) / arg_dlog_y

# Print table of growth contribution for Argentina
data = {'Growth of Y' : arg_dlog_y, 'Growth of TFP' : arg_dlog_A,
        'Growth of K' : arg_dlog_k, 'Growth of L' : arg_dlog_l,
        'TFP Component' : arg_contr_TFP,
        'K Component' : arg_contr_k,
        'L Component' : arg_contr_l}
arg_growth_df = pd.DataFrame(data = data, index = [str(1950 + x) + "-" + str(1951 + x) for x in range(T-1)])
arg_growth_df.index.name = "Time Period"
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(arg_growth_df.iloc[:, 4:])
# Out:
#              TFP Component  K Component  L Component
# Time Period
# 1950-1951         0.320034     0.488734     0.191232
# 1951-1952         1.491704    -0.313009    -0.178695
# 1952-1953         0.266993     0.467516     0.265492
# 1953-1954         0.144155     0.513370     0.342475
# 1954-1955         0.568046     0.269424     0.162530
# 1955-1956         0.078794     0.560865     0.360342
# 1956-1957         0.332283     0.418974     0.248743
# 1957-1958         0.593996     0.259339     0.146666
# 1958-1959         1.440110    -0.251154    -0.188957
# 1959-1960         0.690303     0.218759     0.090938
# 1960-1961         0.040384     0.683927     0.275689
# 1961-1962        -2.826643     2.442421     1.384222
# 1962-1963         1.468322    -0.232348    -0.235974
# 1963-1964         0.689954     0.192102     0.117944
# 1964-1965         0.742740     0.156943     0.100317
# 1965-1966        -7.449349     4.830581     3.618768
# 1966-1967         0.277249     0.412417     0.310334
# 1967-1968         0.581256     0.249354     0.169390
# 1968-1969         0.707095     0.195625     0.097281
# 1969-1970         0.220692     0.508187     0.271121
# 1970-1971         0.370073     0.449428     0.180499
# 1971-1972        -0.063835     0.739761     0.324074
# 1972-1973         0.496817     0.321879     0.181304
# 1973-1974         0.301321     0.223474     0.475205
# 1974-1975         3.595157    -1.840821    -0.754336
# 1975-1976       117.225540  -111.550630    -4.674911
# 1976-1977         0.436266     0.261377     0.302357
# 1977-1978         1.532594    -0.338308    -0.194286
# 1978-1979         0.647160     0.174435     0.178406
# 1979-1980         0.029390     0.827646     0.142964
# 1980-1981         1.167597    -0.138547    -0.029050
# 1981-1982         1.461449    -0.119447    -0.342002
# 1982-1983         0.372645     0.098912     0.528443
# 1983-1984         0.016302     0.170796     0.812902
# 1984-1985         1.090524    -0.020515    -0.070009
# 1985-1986         0.662885     0.041747     0.295367
# 1986-1987         0.240603     0.182298     0.577099
# 1987-1988         1.895208    -0.201468    -0.693740
# 1988-1989         1.098303    -0.014035    -0.084268
# 1989-1990         2.369625     0.035356    -1.404981
# 1990-1991         0.753600     0.024777     0.221623
# 1991-1992         0.823669     0.062920     0.113411
# 1992-1993         0.906428     0.131774    -0.038202
# 1993-1994         0.761949     0.167111     0.070940
# 1994-1995         0.052107    -0.214028     1.161921
# 1995-1996         0.541250     0.130978     0.327771
# 1996-1997         0.429833     0.119268     0.450898
# 1997-1998        -0.089562     0.254101     0.835460
# 1998-1999         1.350611    -0.183643    -0.166967
# 1999-2000         2.498842    -0.603452    -0.895390
# 2000-2001         0.943359    -0.049756     0.106397
# 2001-2002         0.935353     0.022797     0.041850
# 2002-2003         0.596406     0.008618     0.394976
# 2003-2004         0.426893     0.056020     0.517087
# 2004-2005         0.516354     0.079459     0.404188
# 2005-2006         0.582284     0.108081     0.309635
# 2006-2007         0.548757     0.127482     0.323761
# 2007-2008         0.297243     0.283539     0.419218
# 2008-2009         1.215421    -0.089421    -0.126000
# 2009-2010         0.697376     0.092980     0.209643
# 2010-2011         0.541705     0.188204     0.270091
# 2011-2012         2.907888    -0.804005    -1.103882
# 2012-2013         0.146899     0.335582     0.517519
# 2013-2014         1.612229    -0.242714    -0.369515
# 2014-2015         0.140479     0.235279     0.624242
# 2015-2016         1.014235    -0.235124     0.220888
# 2016-2017         0.341474     0.243365     0.415161
# 2017-2018         1.341094    -0.200453    -0.140641
# 2018-2019         1.904580    -0.106729    -0.797850

# %%
# Plot the contribution of TFP
plt.plot([1951 + i for i in range(T-1)], arg_contr_TFP)
plt.title('Contribution of TFP to Real GDP Growth for Argentina', size = 20)
plt.xlabel('Year')
plt.ylabel('Contribution of TFP to real GDP growth')
plt.show()

# %%
# Plot the contribution of capital
plt.plot([1950 + i for i in range(T-1)], arg_contr_k)
plt.title('Contribution of Capital to Real GDP Growth for Argentina', size = 20)
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
# Plot the contribution of labor for Argentina
plt.plot([1950 + i for i in range(T-1)], arg_contr_l)
plt.title('Contribution of Labour to Real GDP Growth for Argentina', size=25)
plt.xlabel('Year')
plt.ylabel('Contribution of Labour to real GDP growth')
# Out:
# Text(0, 0.5, 'Contribution of Labour to real GDP growth')

# %%
#Combining into one graph

plt.plot([1950 + i for i in range(T-1)], arg_contr_TFP)
plt.plot([1950 + i for i in range(T-1)], arg_contr_k)
plt.plot([1950 + i for i in range(T-1)], arg_contr_l)

plt.legend(['TFP Contribution', 'Capital Contribution', 'Labour Contribution'])
plt.title('Contributions to Real GDP Growth for Argentina')
plt.xlabel('Year')
plt.ylabel('Contribution to real GDP growth')
# Out:
# Text(0, 0.5, 'Contribution to real GDP growth')

# %% [markdown]
# Due to the anomalous outlier in 1975-1976, interpretation of this graph is muddled therefore I will work around this by removing it from the dataframe and use linear interpolation to fill in the value I remove.

# %%
#Removing outlier from dataframe
arg_growth_df.loc['1975-1976'][4:] = np.nan
pd.set_option('display.max_rows',500)

#Linear interpolation to fill in the gap in data
arg_growth_df = arg_growth_df.interpolate(method = 'linear')

#New plot
plt.plot([1950 + i for i in range(T-1)], arg_growth_df['TFP Component'])
plt.plot([1950 + i for i in range(T-1)], arg_growth_df['K Component'])
plt.plot([1950 + i for i in range(T-1)], arg_growth_df['L Component'])

plt.legend(['Contribution of TFP', 'Contribution of Capital', 'Contribution of Labour'])
plt.title('Contributions to Real GDP Growth for Argentina with interpolation', size = 20)
plt.xlabel('Year')
plt.ylabel('Contribution to real GDP growth')
# Out:
# Text(0, 0.5, 'Contribution to real GDP growth')

# %%
#Plot percentage change

plt.plot([1950 + i for i in range(T-1)], arg_dlog_A*100)
plt.title('Percentage Change in TFP for Argentina', size=25)
plt.xlabel('Year')
plt.ylabel('Percentage Change')
# Out:
# Text(0, 0.5, 'Percentage Change')

# %% [markdown]
# France

# %%
#Calculating growth contributions
T = fra_df.shape[0]
fra_dlog_y = np.empty(T-1)
fra_dlog_A = np.empty(T-1)
fra_dlog_k = np.empty(T-1)
fra_dlog_l = np.empty(T-1)
for t in range(T-1):
    fra_dlog_y[t] = np.log(fra_df['rgdpna'][t+1]) - np.log(fra_df['rgdpna'][t])
    fra_dlog_A[t] = np.log(fra_df['TFP'][t+1]) - np.log(fra_df['TFP'][t])
    fra_dlog_k[t] = np.log(fra_df['rnna'][t+1]) - np.log(fra_df['rnna'][t])
    fra_dlog_l[t] = np.log(fra_df['emp'][t+1]) - np.log(fra_df['emp'][t])

#TFP contribution
fra_contr_TFP = fra_dlog_A / fra_dlog_y
#Capital contribution
fra_contr_k = ((1 - alpha) * fra_dlog_k) / fra_dlog_y
#Labour contribution
fra_contr_l = (alpha * fra_dlog_l) / fra_dlog_y

# print table of growth contributions
data = {'Growth of Y' : fra_dlog_y, 'Growth of TFP' : fra_dlog_A,
        'Growth of K' : fra_dlog_k, 'Growth of L' : fra_dlog_l,
        'TFP Component' : fra_contr_TFP,
        'K Component' : fra_contr_k,
        'L Component' : fra_contr_l}

fra_growth_df = pd.DataFrame(data = data, index = [str(1950 + x) + "-" + str(1951 + x) for x in range(T-1)])
fra_growth_df.index.name = "Time Period"
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(fra_growth_df.iloc[:, 4:])
# Out:
#              TFP Component  K Component  L Component
# Time Period
# 1950-1951         0.780455     0.131007     0.088537
# 1951-1952         0.701316     0.209704     0.088980
# 1952-1953         0.887858     0.187674    -0.075533
# 1953-1954         0.819050     0.155361     0.025589
# 1954-1955         0.709652     0.186274     0.104074
# 1955-1956         0.601033     0.222962     0.176005
# 1956-1957         0.669961     0.230414     0.099625
# 1957-1958         0.578824     0.483618    -0.062442
# 1958-1959         0.702178     0.440581    -0.142759
# 1959-1960         0.797989     0.186838     0.015173
# 1960-1961         0.723619     0.281957    -0.005576
# 1961-1962         0.777632     0.231083    -0.008715
# 1962-1963         0.677234     0.239857     0.082909
# 1963-1964         0.621216     0.261576     0.117209
# 1964-1965         0.627658     0.327129     0.045213
# 1965-1966         0.578789     0.316002     0.105209
# 1966-1967         0.632917     0.326982     0.040101
# 1967-1968         0.678155     0.363562    -0.041717
# 1968-1969         0.607058     0.241850     0.151093
# 1969-1970         0.574705     0.269718     0.155578
# 1970-1971         0.651639     0.311096     0.037265
# 1971-1972         0.558154     0.357019     0.084826
# 1972-1973         0.592697     0.255520     0.151784
# 1973-1974         0.490917     0.348047     0.161036
# 1974-1975         1.786925    -1.251504     0.464579
# 1975-1976         0.571570     0.266764     0.161666
# 1976-1977         0.509662     0.297775     0.192563
# 1977-1978         0.642926     0.250235     0.106839
# 1978-1979         0.596615     0.271824     0.131561
# 1979-1980         0.230976     0.589554     0.179470
# 1980-1981         0.313309     0.777945    -0.091255
# 1981-1982         0.630028     0.301115     0.068857
# 1982-1983         0.473095     0.515763     0.011142
# 1983-1984         0.858619     0.383608    -0.242227
# 1984-1985         0.685145     0.353722    -0.038867
# 1985-1986         0.551097     0.255425     0.193478
# 1986-1987         0.479689     0.246821     0.273491
# 1987-1988         0.684055     0.153960     0.161985
# 1988-1989         0.606793     0.182349     0.210858
# 1989-1990         0.531011     0.271889     0.197100
# 1990-1991         0.254966     0.671763     0.073270
# 1991-1992         0.911261     0.386283    -0.297544
# 1992-1993         0.596225    -0.749454     1.153229
# 1993-1994         0.636556     0.198576     0.164868
# 1994-1995         0.431876     0.215197     0.352927
# 1995-1996         0.386987     0.302393     0.310620
# 1996-1997         0.576908     0.172581     0.250510
# 1997-1998         0.514956     0.128096     0.356947
# 1998-1999         0.356493     0.154565     0.488942
# 1999-2000         0.417427     0.148131     0.434442
# 2000-2001         0.237679     0.280163     0.482158
# 2001-2002         0.266632     0.428581     0.304787
# 2002-2003         0.349000     0.579408     0.071592
# 2003-2004         0.784019     0.176446     0.039535
# 2004-2005         0.423183     0.303338     0.273479
# 2005-2006         0.484484     0.214985     0.300531
# 2006-2007         0.346517     0.237189     0.416295
# 2007-2008        -2.542448     2.117043     1.425406
# 2008-2009         0.858648    -0.124599     0.265951
# 2009-2010         0.747135     0.194425     0.058440
# 2010-2011         0.557425     0.176829     0.265746
# 2011-2012        -1.072894     1.163455     0.909439
# 2012-2013         0.392626     0.574896     0.032478
# 2013-2014         0.413322     0.326906     0.259772
# 2014-2015         0.557128     0.274373     0.168499
# 2015-2016         0.244908     0.289822     0.465269
# 2016-2017         0.512664     0.155850     0.331486
# 2017-2018         0.371631     0.206187     0.422182
# 2018-2019         0.159399     0.262758     0.577844

# %%
# plot contribution of TFP
plt.plot([1951 + i for i in range(T-1)], fra_contr_TFP)
plt.title('Contribution of TFP to Real GDP Growth for France', size=25)
plt.xlabel('Year')
plt.ylabel('Contribution of TFP to real GDP growth')
# Out:
# Text(0, 0.5, 'Contribution of TFP to real GDP growth')

# %%
# plot contribution of capital

plt.plot([1950 + i for i in range(T-1)], fra_contr_k)
plt.title('Contribution of Capital to Real GDP Growth for France', size=25)
plt.xlabel('Year')
plt.ylabel('Contribution of Capital to real GDP growth')
# Out:
# Text(0, 0.5, 'Contribution of Capital to real GDP growth')

# %%
# plot contribution of capital
plt.plot([1950 + i for i in range(T-1)], fra_contr_l)
plt.title('Contribution of Labour to Real GDP Growth for France', size=25)
plt.xlabel('Year')
plt.ylabel('Contribution of Labour to real GDP growth')
# Out:
# Text(0, 0.5, 'Contribution of Labour to real GDP growth')

# %%
#Combining into one graph

plt.plot([1950 + i for i in range(T-1)], fra_contr_TFP)
plt.plot([1950 + i for i in range(T-1)], fra_contr_k)
plt.plot([1950 + i for i in range(T-1)], fra_contr_l)

plt.legend(['TFP Contribution', 'Capital Contribution', 'Labour Contribution'])
plt.title('Contributions to Real GDP Growth for France')
plt.xlabel('Year')
plt.ylabel('Contribution to real GDP growth')
# Out:
# Text(0, 0.5, 'Contribution to real GDP growth')

# %%
#Plot percentage change
plt.plot([1950 + i for i in range(T-1)], fra_dlog_A*100)
plt.title('Percentage Change in TFP for France', size=25)
plt.xlabel('Year')
plt.ylabel('Percentage Change')
# Out:
# Text(0, 0.5, 'Percentage Change')

# %% [markdown]
# # Additional Graphs for Essay Component

# %%
plt.plot([1950 + i for i in range(T-1)], arg_dlog_y*100)
plt.title('Percentage Change in RGDP for Argentina', size=25)
plt.xlabel('Year')
plt.ylabel('Percentage Change')

print(arg_dlog_y.mean(axis=None))
# Out:
# 0.02320869376552627

# %%
plt.plot([1950 + i for i in range(T-1)], fra_dlog_y*100)
plt.title('Percentage Change in RGDP for France', size=25)
plt.xlabel('Year')
plt.ylabel('Percentage Change')

print(fra_dlog_y.mean(axis=None))
# Out:
# 0.03006898016579207

# %%
#Calculating mean percentage growth of GDP between 1950-1980
fray5080 = fra_dlog_y[0:31]
print(fray5080.mean(axis=None))
# Out:
# 0.04597866399185164

# %%
#Calculating mean percentage growth of GDP between 1980-2019
fray8019 = fra_dlog_y[30:70]
print(fray8019.mean(axis=None))
# Out:
# 0.017830761838053943

# %%
#Calculating mean percentage growth of TFP between 1950-1980
fraA5080 = fra_dlog_A[0:31]
print(fraA5080.mean(axis=None))
# Out:
# 0.029787020702972723

# %%
#Calculating mean percentage growth of TFP between 1980-2019
fraA8019 = fra_dlog_A[30:]
print(fraA8019.mean(axis=None))
# Out:
# 0.008595680517528716

# %% [markdown]
# # Graphs for Comparison

# %%
plt.plot(fra_df['year'], fra_df['TFP'],label='France')
plt.plot(arg_df['year'], arg_df['TFP'],label='Argentina')
plt.title('TFP of France and Argentina')
plt.xlabel('Year')
plt.ylabel('Total Factor Productivity')

plt.legend()
plt.show()

# %%
plt.plot(fra_df['year'], y_fra, label = 'France')
plt.plot(arg_df['year'], y_arg, label = 'Argentina')
plt.title('RGDP of France and Argentina')
plt.xlabel('Year')
plt.ylabel('Total Factor Productivity')

plt.legend()
plt.show()

# %%
plt.plot([1950 + i for i in range(T-1)], fra_contr_k, label = 'France')
plt.plot([1950 + i for i in range(T-1)], arg_contr_k, label = 'Argentina')
plt.title('Contribution of Capital to Real GDP Growth for France and Argentina', size=25)
plt.xlabel('Year')
plt.ylabel('Contribution of Capital to real GDP growth')
# Out:
# Text(0, 0.5, 'Contribution of Capital to real GDP growth')

# %%
plt.plot([1950 + i for i in range(T-1)], fra_contr_l, label = 'France')
plt.plot([1950 + i for i in range(T-1)], arg_contr_l, label = 'Argentina')
plt.title('Contribution of Labour to Real GDP Growth for France and Argentina', size=25)
plt.xlabel('Year')
plt.ylabel('Contribution of Labour to real GDP growth')

plt.legend()
plt.show()

# %%
plt.plot([1950 + i for i in range(T-1)], fra_contr_TFP, label = 'France')
plt.plot([1950 + i for i in range(T-1)], arg_contr_TFP, label = 'Argentina')
plt.title('Contribution of TFP to Real GDP Growth for France and Argentina', size=25)
plt.xlabel('Year')
plt.ylabel('Contribution of TFP to real GDP growth')

plt.legend()
plt.show()

# %%
data = {'TFP': fra_df['TFP']}

df = pd.DataFrame(data)
df = df.set_index(fra_df['year'])

print('France')
# print the dataframe in a table format
print(df.to_string(index=True))
# Out:
# France
#               TFP
# year
# 1950   553.321284
# 1951   577.169374
# 1952   590.217104
# 1953   608.676129
# 1954   636.859535
# 1955   660.972463
# 1956   681.039638
# 1957   705.919327
# 1958   717.135075
# 1959   730.609931
# 1960   777.687001
# 1961   806.230990
# 1962   847.620602
# 1963   884.410796
# 1964   919.864611
# 1965   947.690546
# 1966   976.133431
# 1967  1006.630583
# 1968  1036.320945
# 1969  1080.799509
# 1970  1118.810968
# 1971  1157.222396
# 1972  1186.077392
# 1973  1230.119058
# 1974  1255.813413
# 1975  1234.354494
# 1976  1264.811277
# 1977  1286.956582
# 1978  1319.646115
# 1979  1347.399088
# 1980  1352.282843
# 1981  1356.795576
# 1982  1378.114049
# 1983  1386.177957
# 1984  1404.175067
# 1985  1419.747576
# 1986  1437.940045
# 1987  1455.494783
# 1988  1502.372651
# 1989  1541.641110
# 1990  1565.415374
# 1991  1569.582704
# 1992  1592.441940
# 1993  1586.465445
# 1994  1610.180768
# 1995  1624.743974
# 1996  1633.590096
# 1997  1655.500465
# 1998  1685.832431
# 1999  1706.172307
# 2000  1733.803836
# 2001  1741.917426
# 2002  1747.169597
# 2003  1752.175588
# 2004  1790.931322
# 2005  1803.476875
# 2006  1824.744452
# 2007  1839.956286
# 2008  1828.083695
# 2009  1782.889294
# 2010  1808.793575
# 2011  1830.795721
# 2012  1824.664981
# 2013  1828.786598
# 2014  1835.994016
# 2015  1847.349977
# 2016  1852.285866
# 2017  1873.924983
# 2018  1886.341021
# 2019  1890.848556

# %%
data = {'TFP': arg_df['TFP']}

df = pd.DataFrame(data)
df = df.set_index(arg_df['year'])

print('Argentina')
# print the dataframe in a table format
print(df.to_string(index=True))
# Out:
# Argentina
#               TFP
# year
# 1950  1128.710657
# 1951  1149.630501
# 1952  1048.999284
# 1953  1060.639599
# 1954  1065.549956
# 1955  1107.210485
# 1956  1109.483783
# 1957  1123.473407
# 1958  1166.974182
# 1959  1086.460650
# 1960  1166.640205
# 1961  1168.149828
# 1962  1147.279899
# 1963  1085.957651
# 1964  1143.512972
# 1965  1220.752032
# 1966  1199.500262
# 1967  1208.677628
# 1968  1244.584205
# 1969  1324.205428
# 1970  1333.433275
# 1971  1351.777896
# 1972  1350.004565
# 1973  1374.884467
# 1974  1396.869706
# 1975  1367.315440
# 1976  1349.536455
# 1977  1386.470438
# 1978  1318.613441
# 1979  1377.775574
# 1980  1378.359900
# 1981  1291.583059
# 1982  1232.349644
# 1983  1250.996443
# 1984  1251.401459
# 1985  1156.778250
# 1986  1210.916882
# 1987  1218.226267
# 1988  1173.535731
# 1989  1083.494996
# 1990  1049.440891
# 1991  1131.420560
# 1992  1226.610924
# 1993  1295.920410
# 1994  1353.157816
# 1995  1351.124100
# 1996  1391.041452
# 1997  1438.462591
# 1998  1433.603692
# 1999  1368.445067
# 2000  1341.624839
# 2001  1285.754295
# 2002  1154.253118
# 2003  1214.045456
# 2004  1259.686060
# 2005  1316.079940
# 2006  1376.748913
# 2007  1443.475812
# 2008  1460.641279
# 2009  1356.250535
# 2010  1450.612034
# 2011  1497.160463
# 2012  1452.910458
# 2013  1457.992277
# 2014  1399.386014
# 2015  1404.693078
# 2016  1375.059249
# 2017  1387.481031
# 2018  1341.497875
# 2019  1286.775586
